# %%
import pandas as pd

data = pd.read_excel(r'E:\gitlab\Kaggle_Titanic-master\Kaggle_Titanic-master\BX_pred\DA\合并后的数据_去result.xlsx')
data.head(10)

# %%
del data['Unnamed: 5']
data.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-18385022f6a3> in <module>()
# ----> 1 del data['Unnamed: 5']
#       2 data.head(10)
#
# NameError: name 'data' is not defined

# %%
del data['4. Panel brand: M 品牌']
del data['Unnamed: 1']
data.head(10)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>4. VIB (native product) 型号</th>
#       <th>1. Calendar year / week 年/周</th>
#       <th>PC</th>
#       <th>品牌</th>
#       <th>产品</th>
#       <th>产品子类</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>BBH21634CN</td>
#       <td>7.2017</td>
#       <td>16</td>
#       <td>博世</td>
#       <td>生活家电</td>
#       <td>立式吸尘器T14</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>BBH21634CN</td>
#       <td>11.2017</td>
#       <td>1</td>
#       <td>博世</td>
#       <td>生活家电</td>
#       <td>立式吸尘器T14</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>BBH22451CN</td>
#       <td>51.2016</td>
#       <td>2</td>
#       <td>博世</td>
#       <td>生活家电</td>
#       <td>立式吸尘器T14</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>BBH22451CN</td>
#       <td>7.2017</td>
#       <td>10</td>
#       <td>博世</td>
#       <td>生活家电</td>
#       <td>立式吸尘器T14</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>BBH22455CN</td>
#       <td>51.2016</td>
#       <td>3</td>
#       <td>博世</td>
#       <td>生活家电</td>
#       <td>立式吸尘器T14</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>BBH22455CN</td>
#       <td>3.2017</td>
#       <td>5</td>
#       <td>博世</td>
#       <td>生活家电</td>
#       <td>立式吸尘器T14</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>BBH22455CN</td>
#       <td>12.2017</td>
#       <td>5</td>
#       <td>博世</td>
#       <td>生活家电</td>
#       <td>立式吸尘器T14</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>BCH65PETCN</td>
#       <td>52.2016</td>
#       <td>2</td>
#       <td>博世</td>
#       <td>生活家电</td>
#       <td>立式吸尘器T14</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>BCH65PETCN</td>
#       <td>13.2017</td>
#       <td>3</td>
#       <td>博世</td>
#       <td>生活家电</td>
#       <td>立式吸尘器T14</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>BCH65PETCN</td>
#       <td>19.2017</td>
#       <td>1</td>
#       <td>博世</td>
#       <td>生活家电</td>
#       <td>立式吸尘器T14</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data=data.rename(columns={'4. VIB (native product) 型号': 'VIB'})
data=data.rename(columns={'1. Calendar year / week 年/周': 'T'})
data.head(10)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>VIB</th>
#       <th>T</th>
#       <th>PC</th>
#       <th>品牌</th>
#       <th>产品</th>
#       <th>产品子类</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>BBH21634CN</td>
#       <td>7.2017</td>
#       <td>16</td>
#       <td>博世</td>
#       <td>生活家电</td>
#       <td>立式吸尘器T14</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>BBH21634CN</td>
#       <td>11.2017</td>
#       <td>1</td>
#       <td>博世</td>
#       <td>生活家电</td>
#       <td>立式吸尘器T14</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>BBH22451CN</td>
#       <td>51.2016</td>
#       <td>2</td>
#       <td>博世</td>
#       <td>生活家电</td>
#       <td>立式吸尘器T14</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>BBH22451CN</td>
#       <td>7.2017</td>
#       <td>10</td>
#       <td>博世</td>
#       <td>生活家电</td>
#       <td>立式吸尘器T14</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>BBH22455CN</td>
#       <td>51.2016</td>
#       <td>3</td>
#       <td>博世</td>
#       <td>生活家电</td>
#       <td>立式吸尘器T14</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>BBH22455CN</td>
#       <td>3.2017</td>
#       <td>5</td>
#       <td>博世</td>
#       <td>生活家电</td>
#       <td>立式吸尘器T14</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>BBH22455CN</td>
#       <td>12.2017</td>
#       <td>5</td>
#       <td>博世</td>
#       <td>生活家电</td>
#       <td>立式吸尘器T14</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>BCH65PETCN</td>
#       <td>52.2016</td>
#       <td>2</td>
#       <td>博世</td>
#       <td>生活家电</td>
#       <td>立式吸尘器T14</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>BCH65PETCN</td>
#       <td>13.2017</td>
#       <td>3</td>
#       <td>博世</td>
#       <td>生活家电</td>
#       <td>立式吸尘器T14</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>BCH65PETCN</td>
#       <td>19.2017</td>
#       <td>1</td>
#       <td>博世</td>
#       <td>生活家电</td>
#       <td>立式吸尘器T14</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data.dtypes
# Out:
# VIB     object
# T       object
# PC       int64
# 品牌      object
# 产品      object
# 产品子类    object
# dtype: object
