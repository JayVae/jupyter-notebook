# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r'E:\gitlab\yyzh\bx\data_r6\KG28FA29EC.csv')

# %%
sales=pd.Series(df.groupby('month_r')['PC'].sum())

# %%
plt.rc('font', family='SimHei', size=13)
sales.plot(kind='line',figsize=(10,5))
plt.ylabel('销量',fontsize=18)
plt.xlabel('月份',fontsize=18)
plt.title('KG28FA29EC',fontsize=20)
plt.tick_params(labelsize=12,axis='both')

# %%
sales
# Out:
# month_r
# 24197      9
# 24198     81
# 24199     82
# 24200    431
# 24201    365
# 24202    401
# 24203     80
# 24204    386
# 24205    789
# 24206     -3
# 24207    160
# 24208    285
# 24209     60
# 24210    362
# 24211    196
# Name: PC, dtype: int64

# %%
data=pd.read_csv(r'E:\gitlab\yyzh\bx\data_r6\KG28FA29EC.csv')
forecastnum = 2
