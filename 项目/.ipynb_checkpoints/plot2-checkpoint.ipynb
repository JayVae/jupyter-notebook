# %%
import pandas as pd
import numpy as np

df=pd.read_excel(r'E:/项目/电力大数据/yh_new.xlsx')
df=df.fillna(0)

# %%
loc_list=df['地理区域'].unique()
df.head(10)
# Out:
#                市场成员名称  用户唯一编号 地理区域             行业分类              一级行业  \
# 0        陕西华银科技股份有限公司      49  安康市         16.金属制品业              二、工业
# 1          陕西中汇煤化有限公司      51  渭南市   9.化学原料及化学制品制造业              二、工业
# 2      陕西中兴林产科技股份有限公司      55  咸阳市       一、农、林、牧、渔业        一、农、林、牧、渔业
# 3  中国联合网络通信有限公司陕西省分公司      85  咸阳市   1.电信和其他信息传输服务业  五、信息传输、计算机服务和软件业
# 4   中航飞机股份有限公司西安制动分公司      86  咸阳市          航空航天器制造              二、工业
# 5      西安庆安制冷设备股份有限公司      90  西安市    17.通用及专用设备制造业              二、工业
# 6       陕西斯瑞新材料股份有限公司     109  西安市  15.有色金属冶炼及压延加工业              二、工业
# 7          咸阳华润纺织有限公司     110  咸阳市             二、工业              二、工业
# 8        五环(集团)股份有限公司     111  西安市           （二）制造业              二、工业
# 9     陕西五洲钒金属材料科技有限公司     112  西安市  15.有色金属冶炼及压延加工业              二、工业
#
#              二级行业 最高供电电压       入市日期  入市时间（月）  信息完善程度    ...     2016下平均功率因数  \
# 0          （二）制造业   10kV 2016-01-01       18     9.0    ...        0.968333
# ...

# %%
loc_list=df['地理区域'].unique()
name=['2015上','2015下','2016上','2016下','2017上']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
#中文字体显示  
plt.rc('font', family='SimHei', size=13)
x=np.arange(5)
y=[0,0,0,0,0]
name=['2015上','2015下','2016上','2016下','2017上']
plt.figure()
i=0
y[0]=df.loc[df['地理区域']==loc_list[0]]['2015上用电量'].mean()
y[1]=df.loc[df['地理区域']==loc_list[0]]['2015下用电量'].mean()
y[2]=df.loc[df['地理区域']==loc_list[0]]['2016上用电量'].mean()
y[3]=df.loc[df['地理区域']==loc_list[0]]['2016下用电量'].mean()
y[4]=df.loc[df['地理区域']==loc_list[0]]['2017上用电量'].mean()
plt.plot(x,y,'ys-',label=loc_list[i])
plt.xticks(x,name,rotation=45)
plt.legend(loc='upper left')

# %%
plt.rc('font', family='SimHei', size=20)
name=['2015上','2015下','2016上','2016下','2017上']
x=np.arange(len(name))
y=[0,0,0,0,0]
plt.figure()
fig=plt.figure(figsize=(13,8))
style=['ys-','m*-','rD-','bo-','c+--','gv--','kp--','kv-.','kh-.','bx-.']

for i in range(len(loc_list)):
    y[0] = df.loc[df['地理区域'] == loc_list[i]]['2015上用电量'].mean()
    y[1] = df.loc[df['地理区域'] == loc_list[i]]['2015下用电量'].mean()
    y[2] = df.loc[df['地理区域'] == loc_list[i]]['2016上用电量'].mean()
    y[3] = df.loc[df['地理区域'] == loc_list[i]]['2016下用电量'].mean()
    y[4] = df.loc[df['地理区域'] == loc_list[i]]['2017上用电量'].mean()
    plt.plot(x,y,style[i],label=loc_list[i])
    plt.xlim(-0.5,5.5)
    plt.xticks(x,name,rotation=45)

plt.legend(loc='upper right')
plt.title('不同区域平均用电量')
plt.savefig(r'E:/项目/电力大数据/不同区域平均用电量情况.png')

# %%
work_list=df['一级行业'].unique()
plt.rc('font', family='SimHei', size=20)
name=['2015上','2015下','2016上','2016下','2017上']
x=np.arange(len(name))
y=[0,0,0,0,0]
plt.figure()
fig=plt.figure(figsize=(13,8))
style=['ys-','m*-','rD-','bo-','c+--','gv--','kp--','kv-.','kh-.','bx-.']

for i in range(len(work_list)):
    y[0] = df.loc[df['一级行业'] == work_list[i]]['2015上用电量'].mean()
    y[1] = df.loc[df['一级行业'] == work_list[i]]['2015下用电量'].mean()
    y[2] = df.loc[df['一级行业'] == work_list[i]]['2016上用电量'].mean()
    y[3] = df.loc[df['一级行业'] == work_list[i]]['2016下用电量'].mean()
    y[4] = df.loc[df['一级行业'] == work_list[i]]['2017上用电量'].mean()
    plt.plot(x,y,style[i],label=work_list[i])
    plt.xlim(-0.5,5)
    plt.xticks(x,name,rotation=45)

plt.legend(loc='center right',bbox_to_anchor=(0.98, 0.54),fontsize=12)
plt.title('不同行业平均用电量')
plt.savefig(r'E:/项目/电力大数据/不同行业平均用电量情况.png')

# %%
date_list=df['入市时间（月）'].unique()
plt.rc('font', family='SimHei', size=20)
name=['2015上','2015下','2016上','2016下','2017上']
x=np.arange(len(name))
y=[0,0,0,0,0]
plt.figure()
fig=plt.figure(figsize=(13,8))
style=['ys-','m*-','rD-','bo-','c+--','gv--','kp--','kv-.','kh-.','bx-.']

for i in range(len(date_list)):
    y[0] = df.loc[df['入市时间（月）'] == date_list[i]]['2015上用电量'].mean()
    y[1] = df.loc[df['入市时间（月）'] == date_list[i]]['2015下用电量'].mean()
    y[2] = df.loc[df['入市时间（月）'] == date_list[i]]['2016上用电量'].mean()
    y[3] = df.loc[df['入市时间（月）'] == date_list[i]]['2016下用电量'].mean()
    y[4] = df.loc[df['入市时间（月）'] == date_list[i]]['2017上用电量'].mean()
    plt.plot(x,y,style[i],label=date_list[i])
    plt.xlim(-0.5,4.7)
    plt.xticks(x,name,rotation=45)

plt.legend(loc='upper right',fontsize=13)
plt.title('不同入市时间平均用电量')
plt.savefig(r'E:/项目/电力大数据/不同入市时间平均用电量情况.png')

# %%
df.dtypes
# Out:
# 市场成员名称                 object
# 用户唯一编号                  int64
# 地理区域                   object
# 行业分类                   object
# 一级行业                   object
# 二级行业                   object
# 最高供电电压                 object
# 入市日期           datetime64[ns]
# 入市时间（月）                 int64
# 信息完善程度                float64
# 2015上用电量              float64
# 2015下用电量              float64
# 2016上用电量              float64
# 2016下用电量              float64
# 2017上用电量              float64
# 2015上用电偏差量            float64
# 2015下用电偏差量            float64
# 2016上用电偏差量            float64
# 2016下用电偏差量            float64
# 2017上用电偏差量            float64
# 2015上用电偏差比例           float64
# 2015下用电偏差比例           float64
# 2016上用电偏差比例           float64
# 2016下用电偏差比例           float64
# 2017上用电偏差比例           float64
# 期初余额                  float64
# 期初余额占比                float64
# 2015一季度电费             float64
# 2015二季度电费             float64
# 2015三季度电费             float64
#                     ...
# ...

# %%
class_list=df['最高供电电压'].unique()
plt.rc('font', family='SimHei', size=20)
name=['2015上','2015下','2016上','2016下','2017上']
x=np.arange(len(name))
y=[0,0,0,0,0]
plt.figure()
fig=plt.figure(figsize=(13,8))
style=['ys-','m*-','rD-','bo-','c+--','gv--','kp--','kv-.','kh-.','bx-.']

for i in range(len(class_list)):
    y[0] = df.loc[df['最高供电电压'] == class_list[i]]['2015上用电量'].mean()
    y[1] = df.loc[df['最高供电电压'] == class_list[i]]['2015下用电量'].mean()
    y[2] = df.loc[df['最高供电电压'] == class_list[i]]['2016上用电量'].mean()
    y[3] = df.loc[df['最高供电电压'] == class_list[i]]['2016下用电量'].mean()
    y[4] = df.loc[df['最高供电电压'] == class_list[i]]['2017上用电量'].mean()
    plt.plot(x,y,style[i],label=class_list[i])
    plt.xlim(-0.5,4.7)
    plt.xticks(x,name,rotation=45)

plt.legend(loc='upper right',fontsize=13)
plt.title('不同电压等级平均用电量')
plt.savefig(r'E:/项目/电力大数据/不同电压等级平均用电量情况.png')

# %%
df=pd.read_excel(r'E:/项目/电力大数据/yh_new.xlsx')
df=df.fillna(0)
date_list=df['入市时间（月）'].unique()
date_class=['2015年以前','2015.1-2015.6','2015.7-2015.12','2016.1-2016.6','2016.7-2016.12']

plt.rc('font', family='SimHei', size=20)
name=['2015上','2015下','2016上','2016下','2017上']
x=np.arange(len(name))
y=[0,0,0,0,0]
plt.figure()
fig=plt.figure(figsize=(13,8))
style=['ys-','m*-','rD-','bo-','c+--','gv--','kp--','kv-.','kh-.','bx-.']

for i in range(len(date_list)):
    y[0] = df.loc[df['入市时间（月）'] == date_list[i]]['2015上用电量'].mean()
    y[1] = df.loc[df['入市时间（月）'] == date_list[i]]['2015下用电量'].mean()
    y[2] = df.loc[df['入市时间（月）'] == date_list[i]]['2016上用电量'].mean()
    y[3] = df.loc[df['入市时间（月）'] == date_list[i]]['2016下用电量'].mean()
    y[4] = df.loc[df['入市时间（月）'] == date_list[i]]['2017上用电量'].mean()
    plt.plot(x,y,style[i],label=date_class[i])
    plt.xlim(-0.1,4.1)
    plt.xticks(x,name,rotation=45)

plt.legend(loc='upper right',bbox_to_anchor=(1, 0.9),fontsize=13)
plt.title('不同入市时间平均用电量')
plt.savefig(r'E:/项目/电力大数据/不同入市时间平均用电量情况.png')

# %%
plt.rc('font', family='SimHei', size=20)
plt.rcParams['axes.unicode_minus']=False
loc_list=df['地理区域'].unique()
name=['2015上','2015下','2016上','2016下','2017上']
x=np.arange(len(name))
y=[0,0,0,0,0]
plt.figure()
fig=plt.figure(figsize=(13,8))
style=['ys-','m*-','rD-','bo-','c+--','gv--','kp--','kv-.','kh-.','bx-.']

for i in range(len(loc_list)):
    y[0] = df.loc[df['地理区域'] == loc_list[i]]['2015上用电偏差量'].mean()
    y[1] = df.loc[df['地理区域'] == loc_list[i]]['2015下用电偏差量'].mean()
    y[2] = df.loc[df['地理区域'] == loc_list[i]]['2016上用电偏差量'].mean()
    y[3] = df.loc[df['地理区域'] == loc_list[i]]['2016下用电偏差量'].mean()
    y[4] = df.loc[df['地理区域'] == loc_list[i]]['2017上用电偏差量'].mean()
    plt.plot(x,y,style[i],label=loc_list[i])
    plt.xlim(-0.5,5.5)
    plt.xticks(x,name,rotation=45)

plt.legend(loc='upper right')
plt.title('不同区域平均偏差电量')
plt.savefig(r'E:/项目/电力大数据/不同区域平均偏差电量情况.png')

# %%
work_list=df['一级行业'].unique()
plt.rc('font', family='SimHei', size=20)
name=['2015上','2015下','2016上','2016下','2017上']
x=np.arange(len(name))
y=[0,0,0,0,0]
plt.figure()
fig=plt.figure(figsize=(13,8))
style=['ys-','m*-','rD-','bo-','c+--','gv--','kp--','kv-.','kh-.','bx-.']

for i in range(len(work_list)):
    y[0] = df.loc[df['一级行业'] == work_list[i]]['2015上用电偏差量'].mean()
    y[1] = df.loc[df['一级行业'] == work_list[i]]['2015下用电偏差量'].mean()
    y[2] = df.loc[df['一级行业'] == work_list[i]]['2016上用电偏差量'].mean()
    y[3] = df.loc[df['一级行业'] == work_list[i]]['2016下用电偏差量'].mean()
    y[4] = df.loc[df['一级行业'] == work_list[i]]['2017上用电偏差量'].mean()
    plt.plot(x,y,style[i],label=work_list[i])
    plt.xlim(-0.5,5)
    plt.xticks(x,name,rotation=45)

plt.legend(loc='upper right',fontsize=12)
plt.title('不同行业平均用电偏差量')
plt.savefig(r'E:/项目/电力大数据/不同行业平均用电偏差量情况.png')

# %%
class_list=df['最高供电电压'].unique()
plt.rc('font', family='SimHei', size=20)
name=['2015上','2015下','2016上','2016下','2017上']
x=np.arange(len(name))
y=[0,0,0,0,0]
plt.figure()
fig=plt.figure(figsize=(13,8))
style=['ys-','m*-','rD-','bo-','c+--','gv--','kp--','kv-.','kh-.','bx-.']

for i in range(len(class_list)):
    y[0] = df.loc[df['最高供电电压'] == class_list[i]]['2015上用电偏差量'].mean()
    y[1] = df.loc[df['最高供电电压'] == class_list[i]]['2015下用电偏差量'].mean()
    y[2] = df.loc[df['最高供电电压'] == class_list[i]]['2016上用电偏差量'].mean()
    y[3] = df.loc[df['最高供电电压'] == class_list[i]]['2016下用电偏差量'].mean()
    y[4] = df.loc[df['最高供电电压'] == class_list[i]]['2017上用电偏差量'].mean()
    plt.plot(x,y,style[i],label=class_list[i])
    plt.xlim(-0.5,4.7)
    plt.xticks(x,name,rotation=45)

plt.legend(loc='upper right',fontsize=13)
plt.title('不同电压等级平均用电偏差量')
plt.savefig(r'E:/项目/电力大数据/不同电压等级平均用电偏差量情况.png')

# %%
df=pd.read_excel(r'E:/项目/电力大数据/yh_new.xlsx')
df=df.fillna(0)
date_list=df['入市时间（月）'].unique()
date_class=['2015年以前','2015.1-2015.6','2015.7-2015.12','2016.1-2016.6','2016.7-2016.12']

plt.rc('font', family='SimHei', size=20)
name=['2015上','2015下','2016上','2016下','2017上']
x=np.arange(len(name))
y=[0,0,0,0,0]
plt.figure()
fig=plt.figure(figsize=(13,8))
style=['ys-','m*-','rD-','bo-','c+--','gv--','kp--','kv-.','kh-.','bx-.']

for i in range(len(date_list)):
    y[0] = df.loc[df['入市时间（月）'] == date_list[i]]['2015上用电偏差量'].mean()
    y[1] = df.loc[df['入市时间（月）'] == date_list[i]]['2015下用电偏差量'].mean()
    y[2] = df.loc[df['入市时间（月）'] == date_list[i]]['2016上用电偏差量'].mean()
    y[3] = df.loc[df['入市时间（月）'] == date_list[i]]['2016下用电偏差量'].mean()
    y[4] = df.loc[df['入市时间（月）'] == date_list[i]]['2017上用电偏差量'].mean()
    plt.plot(x,y,style[i],label=date_class[i])
    plt.xlim(-0.1,4.1)
    plt.xticks(x,name,rotation=45)

plt.legend(loc='upper right',fontsize=13)
plt.title('不同入市时间平均用电偏差量')
plt.savefig(r'E:/项目/电力大数据/不同入市时间平均用电偏差量情况.png')

# %%
loc_list=df['地理区域'].unique()
name=['2015上','2015下','2016上','2016下','2017上']
x=np.arange(len(name))
y=[0,0,0,0,0]
plt.figure()
fig=plt.figure(figsize=(13,8))
style=['ys-','m*-','rD-','bo-','c+--','gv--','kp--','kv-.','kh-.','bx-.']

for i in range(len(loc_list)):
    y[0] = df.loc[df['地理区域'] == loc_list[i]]['2015上用电偏差比例'].mean()
    y[1] = df.loc[df['地理区域'] == loc_list[i]]['2015下用电偏差比例'].mean()
    y[2] = df.loc[df['地理区域'] == loc_list[i]]['2016上用电偏差比例'].mean()
    y[3] = df.loc[df['地理区域'] == loc_list[i]]['2016下用电偏差比例'].mean()
    y[4] = df.loc[df['地理区域'] == loc_list[i]]['2017上用电偏差比例'].mean()
    plt.plot(x,y,style[i],label=loc_list[i])
    plt.xlim(-0.5,5.5)
    plt.xticks(x,name,rotation=45)

plt.legend(loc='upper right')
plt.title('不同区域平均用电偏差比例')
plt.savefig(r'E:/项目/电力大数据/不同区域平均用电偏差比例情况.png')

# %%
work_list=df['一级行业'].unique()
plt.rc('font', family='SimHei', size=20)
name=['2015上','2015下','2016上','2016下','2017上']
x=np.arange(len(name))
y=[0,0,0,0,0]
plt.figure()
fig=plt.figure(figsize=(13,8))
style=['ys-','m*-','rD-','bo-','c+--','gv--','kp--','kv-.','kh-.','bx-.']

for i in range(len(work_list)):
    y[0] = df.loc[df['一级行业'] == work_list[i]]['2015上用电偏差比例'].mean()
    y[1] = df.loc[df['一级行业'] == work_list[i]]['2015下用电偏差比例'].mean()
    y[2] = df.loc[df['一级行业'] == work_list[i]]['2016上用电偏差比例'].mean()
    y[3] = df.loc[df['一级行业'] == work_list[i]]['2016下用电偏差比例'].mean()
    y[4] = df.loc[df['一级行业'] == work_list[i]]['2017上用电偏差比例'].mean()
    plt.plot(x,y,style[i],label=work_list[i])
    plt.xlim(-0.5,5)
    plt.xticks(x,name,rotation=45)

plt.legend(loc='upper right',fontsize=12)
plt.title('不同行业平均用电偏差比例')
plt.savefig(r'E:/项目/电力大数据/不同行业平均用电偏差比例情况.png')

# %%
class_list=df['最高供电电压'].unique()
plt.rc('font', family='SimHei', size=20)
name=['2015上','2015下','2016上','2016下','2017上']
x=np.arange(len(name))
y=[0,0,0,0,0]
plt.figure()
fig=plt.figure(figsize=(13,8))
style=['ys-','m*-','rD-','bo-','c+--','gv--','kp--','kv-.','kh-.','bx-.']

for i in range(len(class_list)):
    y[0] = df.loc[df['最高供电电压'] == class_list[i]]['2015上用电偏差比例'].mean()
    y[1] = df.loc[df['最高供电电压'] == class_list[i]]['2015下用电偏差比例'].mean()
    y[2] = df.loc[df['最高供电电压'] == class_list[i]]['2016上用电偏差比例'].mean()
    y[3] = df.loc[df['最高供电电压'] == class_list[i]]['2016下用电偏差比例'].mean()
    y[4] = df.loc[df['最高供电电压'] == class_list[i]]['2017上用电偏差比例'].mean()
    plt.plot(x,y,style[i],label=class_list[i])
    plt.xlim(-0.5,4.7)
    plt.xticks(x,name,rotation=45)

plt.legend(loc='upper right',fontsize=13)
plt.title('不同电压等级平均用电偏差比例')
plt.savefig(r'E:/项目/电力大数据/不同电压等级平均用电偏差比例情况.png')

# %%
df=pd.read_excel(r'E:/项目/电力大数据/yh_new.xlsx')
df=df.fillna(0)
date_list=df['入市时间（月）'].unique()
date_class=['2015年以前','2015.1-2015.6','2015.7-2015.12','2016.1-2016.6','2016.7-2016.12']

plt.rc('font', family='SimHei', size=20)
name=['2015上','2015下','2016上','2016下','2017上']
x=np.arange(len(name))
y=[0,0,0,0,0]
plt.figure()
fig=plt.figure(figsize=(13,8))
style=['ys-','m*-','rD-','bo-','c+--','gv--','kp--','kv-.','kh-.','bx-.']

for i in range(len(date_list)):
    y[0] = df.loc[df['入市时间（月）'] == date_list[i]]['2015上用电偏差比例'].mean()
    y[1] = df.loc[df['入市时间（月）'] == date_list[i]]['2015下用电偏差比例'].mean()
    y[2] = df.loc[df['入市时间（月）'] == date_list[i]]['2016上用电偏差比例'].mean()
    y[3] = df.loc[df['入市时间（月）'] == date_list[i]]['2016下用电偏差比例'].mean()
    y[4] = df.loc[df['入市时间（月）'] == date_list[i]]['2017上用电偏差比例'].mean()
    plt.plot(x,y,style[i],label=date_class[i])
    plt.xlim(-0.1,4.1)
    plt.xticks(x,name,rotation=45)

plt.legend(loc='upper right',fontsize=13)
plt.title('不同入市时间平均用电偏差比例')
plt.savefig(r'E:/项目/电力大数据/不同入市时间平均用电偏差比例情况.png')

# %%
df[df['地理区域'] == loc_list[0]]['2015上用电偏差比例'].mean()
# Out:
# 0.22159709299999999

# %%
fig=plt.figure(figsize=(10,6))
plt.rc('font', family='SimHei', size=15)
y=[3737348.124,3768725.831,7100839.006,2682931.271,5848497.932]
name=['2015上','2015下','2016上','2016下','2017上']
plt.plot(x,y,style[1])
plt.xlim(-0.1,4.1)
plt.xticks(x,name,rotation=45)
plt.title('市场整体电量偏差量变化趋势图')
plt.xlabel('时间')
plt.ylabel('电量偏差量/MWh')
plt.savefig(r'E:/项目/电力大数据/市场整体电量偏差量变化趋势图.png')

# %%
fig=plt.figure(figsize=(10,6))
plt.rc('font', family='SimHei', size=15)
y=[2.59075686,2.570263409,1.735658435,0.227549366,0.565172521]
name=['2015上','2015下','2016上','2016下','2017上']
plt.plot(x,y,style[1])
plt.xlim(-0.1,4.1)
plt.xticks(x,name,rotation=45)
plt.title('市场整体电量偏差比例变化趋势图')
plt.xlabel('时间')
plt.ylabel('电量偏差量/%')
plt.yticks([0,0.5,1,1.5,2,2.5,3])
plt.savefig(r'E:/项目/电力大数据/市场整体电量偏差比例变化趋势图.png')

# %%
loc_list=df['地理区域'].unique()
name=['2015上','2015下','2016上','2016下','2017上']
x=np.arange(len(name))
y=[0,0,0,0,0]
plt.figure()
fig=plt.figure(figsize=(13,8))
style=['ys-','m*-','rD-','bo-','c+--','gv--','kp--','kv-.','kh-.','bx-.']

for i in range(len(loc_list)):
    y[0] = df.loc[df['地理区域'] == loc_list[i]]['2015上电费'].mean()
    y[1] = df.loc[df['地理区域'] == loc_list[i]]['2015下电费'].mean()
    y[2] = df.loc[df['地理区域'] == loc_list[i]]['2016上电费'].mean()
    y[3] = df.loc[df['地理区域'] == loc_list[i]]['2016下电费'].mean()
    y[4] = df.loc[df['地理区域'] == loc_list[i]]['2017上电费'].mean()
    plt.plot(x,y,style[i],label=loc_list[i])
    plt.xlim(-0.5,5.5)
    plt.xticks(x,name,rotation=45)

plt.legend(loc='upper right')
plt.title('不同区域半年平均电费')
plt.savefig(r'E:/项目/电力大数据/不同区域半年平均电费情况.png')

# %%
work_list=df['一级行业'].unique()
plt.rc('font', family='SimHei', size=20)
name=['2015上','2015下','2016上','2016下','2017上']
x=np.arange(len(name))
y=[0,0,0,0,0]
plt.figure()
fig=plt.figure(figsize=(13,8))
style=['ys-','m*-','rD-','bo-','c+--','gv--','kp--','kv-.','kh-.','bx-.']

for i in range(len(work_list)):
    y[0] = df.loc[df['一级行业'] == work_list[i]]['2015上电费'].mean()
    y[1] = df.loc[df['一级行业'] == work_list[i]]['2015下电费'].mean()
    y[2] = df.loc[df['一级行业'] == work_list[i]]['2016上电费'].mean()
    y[3] = df.loc[df['一级行业'] == work_list[i]]['2016下电费'].mean()
    y[4] = df.loc[df['一级行业'] == work_list[i]]['2017上电费'].mean()
    plt.plot(x,y,style[i],label=work_list[i])
    plt.xlim(-0.5,5)
    plt.xticks(x,name,rotation=45)

plt.legend(loc='upper right',bbox_to_anchor=(1, 0.9),fontsize=12)
plt.title('不同行业平均电费')
plt.savefig(r'E:/项目/电力大数据/不同行业平均电费情况.png')

# %%
class_list=df['最高供电电压'].unique()
plt.rc('font', family='SimHei', size=20)
name=['2015上','2015下','2016上','2016下','2017上']
x=np.arange(len(name))
y=[0,0,0,0,0]
plt.figure()
fig=plt.figure(figsize=(13,8))
style=['ys-','m*-','rD-','bo-','c+--','gv--','kp--','kv-.','kh-.','bx-.']

for i in range(len(class_list)):
    y[0] = df.loc[df['最高供电电压'] == class_list[i]]['2015上电费'].mean()
    y[1] = df.loc[df['最高供电电压'] == class_list[i]]['2015下电费'].mean()
    y[2] = df.loc[df['最高供电电压'] == class_list[i]]['2016上电费'].mean()
    y[3] = df.loc[df['最高供电电压'] == class_list[i]]['2016下电费'].mean()
    y[4] = df.loc[df['最高供电电压'] == class_list[i]]['2017上电费'].mean()
    plt.plot(x,y,style[i],label=class_list[i])
    plt.xlim(-0.5,4.7)
    plt.xticks(x,name,rotation=45)

plt.legend(loc='upper right',fontsize=13)
plt.title('不同电压等级平均电费')
plt.savefig(r'E:/项目/电力大数据/不同电压等级平均电费情况.png')

# %%
df=pd.read_excel(r'E:/项目/电力大数据/yh_new.xlsx')
df=df.fillna(0)
date_list=df['入市时间（月）'].unique()
date_class=['2015年以前','2015.1-2015.6','2015.7-2015.12','2016.1-2016.6','2016.7-2016.12']

plt.rc('font', family='SimHei', size=20)
name=['2015上','2015下','2016上','2016下','2017上']
x=np.arange(len(name))
y=[0,0,0,0,0]
plt.figure()
fig=plt.figure(figsize=(13,8))
style=['ys-','m*-','rD-','bo-','c+--','gv--','kp--','kv-.','kh-.','bx-.']

for i in range(len(date_list)):
    y[0] = df.loc[df['入市时间（月）'] == date_list[i]]['2015上电费'].mean()
    y[1] = df.loc[df['入市时间（月）'] == date_list[i]]['2015下电费'].mean()
    y[2] = df.loc[df['入市时间（月）'] == date_list[i]]['2016上电费'].mean()
    y[3] = df.loc[df['入市时间（月）'] == date_list[i]]['2016下电费'].mean()
    y[4] = df.loc[df['入市时间（月）'] == date_list[i]]['2017上电费'].mean()
    plt.plot(x,y,style[i],label=date_class[i])
    plt.xlim(-0.1,4.1)
    plt.xticks(x,name,rotation=45)

plt.legend(loc='upper right',bbox_to_anchor=(1, 0.9),fontsize=13)
plt.title('不同入市时间平均电费')
plt.savefig(r'E:/项目/电力大数据/不同入市时间平均电费情况.png')

# %%
y=[None ,None ,0,1,0.8]
x=[1,2,3,4,5]
plt.xlim(0,5)
plt.plot(x,y)

# %%
df['2015上缴费偏差比例']=df['2015二季度缴费']/df['2015上应收电费']
df['2015下缴费偏差比例']=df['2015四季度缴费']/df['2015下累计应收电费']
df['2016上缴费偏差比例']=df['2016二季度缴费']/df['2016上累计应收电费']
df['2016下缴费偏差比例']=df['2016四季度缴费']/df['2016下累计应收电费']
df['2017上缴费偏差比例']=df['2017二季度缴费']/df['2017上累计应收电费']
df['2015上缴费偏差比例']
# Out:
# 0           NaN
# 1      0.022258
# 2      0.000000
# 3           NaN
# 4      0.002311
# 5      0.000000
# 6      0.000000
# 7     -0.004834
# 8      0.000000
# 9      0.000000
# 10     0.000000
# 11         -inf
# 12     0.000000
# 13          NaN
# 14    -0.087690
# 15     0.000000
# 16     0.000000
# 17     0.000000
# 18     0.000000
# 19     0.000000
# 20          NaN
# 21     0.000000
# 22     0.000000
# 23     0.000000
# 24     0.000000
# 25          NaN
# 26     0.000000
# 27          NaN
# 28     0.000000
# 29     0.000000
#          ...
# 211    0.000000
# 212    0.000000
# 213    0.000000
# 214   -0.035902
# 215    0.000000
# 216    0.136852
# 217         NaN
# 218    0.028685
# 219   -0.114930
# 220    0.000000
# 221    0.255522
# 222    0.000000
# 223   -0.483242
# 224    0.000000
# 225   -0.005476
# 226    0.000000
# 227    0.000000
# 228    0.000000
# 229    0.000000
# 230    0.129089
# 231    0.000000
# 232    0.257625
# 233    0.000000
# 234    0.000000
# ...

# %%
loc_list=df['地理区域'].unique()
name=['2015上','2015下','2016上','2016下','2017上']
x=np.arange(len(name))
y=[0,0,0,0,0]
plt.figure()
fig=plt.figure(figsize=(13,8))
style=['ys-','m*-','rD-','bo-','c+--','gv--','kp--','kv-.','kh-.','bx-.']

for i in range(len(loc_list)):
    y[0] = df.loc[df['地理区域'] == loc_list[i]]['2015上缴费偏差比例'].mean()
    y[1] = df.loc[df['地理区域'] == loc_list[i]]['2015下缴费偏差比例'].mean()
    y[2] = df.loc[df['地理区域'] == loc_list[i]]['2016上缴费偏差比例'].mean()
    y[3] = df.loc[df['地理区域'] == loc_list[i]]['2016下缴费偏差比例'].mean()
    y[4] = df.loc[df['地理区域'] == loc_list[i]]['2017上缴费偏差比例'].mean()
    plt.plot(x,y,style[i],label=loc_list[i])
    plt.xlim(-0.5,5.5)
    plt.xticks(x,name,rotation=45)

plt.legend(loc='upper right')
plt.title('不同区域半年缴费偏差比例')
plt.savefig(r'E:/项目/电力大数据/不同区域半年缴费偏差比例情况.png')

# %%
work_list=df['一级行业'].unique()
plt.rc('font', family='SimHei', size=20)
name=['2015上','2015下','2016上','2016下','2017上']
x=np.arange(len(name))
y=[0,0,0,0,0]
plt.figure()
fig=plt.figure(figsize=(13,8))
style=['ys-','m*-','rD-','bo-','c+--','gv--','kp--','kv-.','kh-.','bx-.']

for i in range(len(work_list)):
    y[0] = df.loc[df['一级行业'] == work_list[i]]['2015上缴费偏差比例'].mean()
    y[1] = df.loc[df['一级行业'] == work_list[i]]['2015下缴费偏差比例'].mean()
    y[2] = df.loc[df['一级行业'] == work_list[i]]['2016上缴费偏差比例'].mean()
    y[3] = df.loc[df['一级行业'] == work_list[i]]['2016下缴费偏差比例'].mean()
    y[4] = df.loc[df['一级行业'] == work_list[i]]['2017上缴费偏差比例'].mean()
    plt.plot(x,y,style[i],label=work_list[i])
    plt.xlim(-0.5,5)
    plt.xticks(x,name,rotation=45)

plt.legend(loc='upper right',fontsize=12)
plt.title('不同行业缴费偏差比例')
plt.savefig(r'E:/项目/电力大数据/不同行业缴费偏差比例情况.png')

# %%
class_list=df['最高供电电压'].unique()
plt.rc('font', family='SimHei', size=20)
name=['2015上','2015下','2016上','2016下','2017上']
x=np.arange(len(name))
y=[0,0,0,0,0]
plt.figure()
fig=plt.figure(figsize=(13,8))
style=['ys-','m*-','rD-','bo-','c+--','gv--','kp--','kv-.','kh-.','bx-.']

for i in range(len(class_list)):
    y[0] = df.loc[df['最高供电电压'] == class_list[i]]['2015上缴费偏差比例'].mean()
    y[1] = df.loc[df['最高供电电压'] == class_list[i]]['2015下缴费偏差比例'].mean()
    y[2] = df.loc[df['最高供电电压'] == class_list[i]]['2016上缴费偏差比例'].mean()
    y[3] = df.loc[df['最高供电电压'] == class_list[i]]['2016下缴费偏差比例'].mean()
    y[4] = df.loc[df['最高供电电压'] == class_list[i]]['2017上缴费偏差比例'].mean()
    plt.plot(x,y,style[i],label=class_list[i])
    plt.xlim(-0.5,4.7)
    plt.xticks(x,name,rotation=45)

plt.legend(loc='upper right',fontsize=13)
plt.title('不同电压等级缴费偏差比例')
plt.savefig(r'E:/项目/电力大数据/不同电压等级缴费偏差比例情况.png')

# %%
date_list=df['入市时间（月）'].unique()
date_class=['2015年以前','2015.1-2015.6','2015.7-2015.12','2016.1-2016.6','2016.7-2016.12']

plt.rc('font', family='SimHei', size=20)
name=['2015上','2015下','2016上','2016下','2017上']
x=np.arange(len(name))
y=[0,0,0,0,0]
plt.figure()
fig=plt.figure(figsize=(13,8))
style=['ys-','m*-','rD-','bo-','c+--','gv--','kp--','kv-.','kh-.','bx-.']

for i in range(len(date_list)):
    y[0] = df.loc[df['入市时间（月）'] == date_list[i]]['2015上缴费偏差比例'].mean()
    y[1] = df.loc[df['入市时间（月）'] == date_list[i]]['2015下缴费偏差比例'].mean()
    y[2] = df.loc[df['入市时间（月）'] == date_list[i]]['2016上缴费偏差比例'].mean()
    y[3] = df.loc[df['入市时间（月）'] == date_list[i]]['2016下缴费偏差比例'].mean()
    y[4] = df.loc[df['入市时间（月）'] == date_list[i]]['2017上缴费偏差比例'].mean()
    plt.plot(x,y,style[i],label=date_class[i])
    plt.xlim(-0.1,4.1)
    plt.xticks(x,name,rotation=45)

plt.legend(loc='upper right',bbox_to_anchor=(1, 0.68),fontsize=13)
plt.title('不同入市时间缴费偏差比例')
plt.savefig(r'E:/项目/电力大数据/不同入市时间缴费偏差比例情况.png')
