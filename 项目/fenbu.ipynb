# %%
df['尺寸'].value_counts()
# Out:
# M    94
# S    25
# D    15
# T     4
# Name: 尺寸, dtype: int64

# %%
df['尺寸'].value_counts().plot(title="State",kind="bar")

# %%
#coding=utf-8
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rc('font', family='SimHei', size=13)

df=pd.read_excel(r'C:\Users\dell\Desktop\BX\指标\拆解\西门子洗衣机_cj.xlsx',sheetname='带平均销量')
df["尺寸"].value_counts().plot(title="尺寸",kind="pie",autopct='%.1f',figsize=(10, 10))

# %%
df["尺寸"].value_counts()
# Out:
# M    94
# S    25
# D    15
# Name: 尺寸, dtype: int64

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
ax.hist(df[u"转速1"]*1000+df['转速2']*100,bins=100)
plt.title(u'转速分布')
plt.xlabel(u'转速')
plt.ylabel(u'Counts')
plt.show()

# %%
df["平台"].value_counts().plot(title="尺寸",kind="pie",autopct='%.1f',figsize=(10, 10))

# %%
df["平台"].value_counts()
# Out:
# P    23
# U    17
# X    16
# E    15
# K    11
# H    11
# N    11
# S     8
# M     7
# L     6
# G     4
# O     3
# Y     2
# Name: 平台, dtype: int64

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
ax.hist(df["平台"])
plt.title(u'平台分布')
plt.xlabel(u'平台')
plt.ylabel(u'Counts')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-b87ed99043c1> in <module>()
#       1 fig=plt.figure()
#       2 ax=fig.add_subplot(1,1,1)
# ----> 3 ax.hist(df["平台"])
#       4 plt.title(u'平台分布')
#       5 plt.xlabel(u'平台')
#
# D:\develop\Anaconda\envs\python35\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# D:\develop\Anaconda\envs\python35\lib\site-packages\matplotlib\axes\_axes.py in hist(***failed resolving arguments***)
#    6178             xmax = -np.inf
#    6179             for xi in x:
# -> 6180                 if len(xi) > 0:
# ...

# %%
df["显示"].value_counts()
# Out:
# 2    53
# 1    23
# 4    21
# 5    12
# 3    10
# 0     9
# 8     2
# 7     2
# 6     2
# Name: 显示, dtype: int64

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
ax.hist(df[u'显示'],bins=100)
plt.title(u'显示分布')
plt.xlabel(u'显示')
plt.ylabel(u'Counts')
plt.show()

# %%
df["颜色"].value_counts()
# Out:
# 8    64
# 0    58
# 9     7
# 7     3
# 1     2
# Name: 颜色, dtype: int64

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
ax.hist(df[u'颜色'],bins=100)
plt.title(u'颜色分布')
plt.xlabel(u'颜色')
plt.ylabel(u'Counts')
plt.show()

# %%
df["颜色"].value_counts().plot(title="颜色",kind="pie",autopct='%.1f',figsize=(10, 10))

# %%
data=pd.read_excel(r'C:\Users\dell\Desktop\BX\指标\拆解\西门子洗衣机_cj.xlsx',sheetname='西门子洗衣机_销量')
boxplots=data['销量'].boxplot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-6efc7a751e5a> in <module>()
#       1 data=pd.read_excel(r'C:\Users\dell\Desktop\BX\指标\拆解\西门子洗衣机_cj.xlsx',sheetname='西门子洗衣机_销量')
# ----> 2 boxplots=data['销量'].boxplot()
#
# D:\develop\Anaconda\envs\python35\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'boxplot'

# %%
#coding=utf-8
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rc('font', family='SimHei', size=13)

df=pd.read_excel(r'C:\Users\dell\Desktop\BX\指标\拆解\西门子洗衣机_cj.xlsx',sheetname='西门子洗衣机_销量')

# %%
df.describe()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>转速1</th>
#       <th>转速2</th>
#       <th>显示</th>
#       <th>颜色</th>
#       <th>销量</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>130.000000</td>
#       <td>130.000000</td>
#       <td>130.000000</td>
#       <td>130.000000</td>
#       <td>130.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>0.861538</td>
#       <td>2.684615</td>
#       <td>2.553846</td>
#       <td>4.476923</td>
#       <td>1346.007692</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>0.346720</td>
#       <td>2.509006</td>
#       <td>1.689280</td>
#       <td>4.013959</td>
# ...

# %%
df.dtypes
# Out:
# 产品代号    object
# 尺寸      object
# 转速1      int64
# 转速2      int64
# 平台      object
# 显示       int64
# 安装      object
# 颜色       int64
# 国家      object
# 国家2     object
# 销量       int64
# dtype: object

# %%
df2=df['销量']
df2.describe()
# Out:
# count     130.000000
# mean     1346.007692
# std      1715.081057
# min         9.000000
# 25%       224.750000
# 50%       658.500000
# 75%      1792.000000
# max      8738.000000
# Name: 销量, dtype: float64

# %%
df3=pd.DataFrame(df2)
boxplots=df3.boxplot()

# %%
import numpy as np
data_size=df.groupby('尺寸')
data_size['销量'].agg([np.sum,np.mean,np.std])
data_size

# %%
data_size['销量']

# %%
data_size.head(10)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>产品代号</th>
#       <th>尺寸</th>
#       <th>转速1</th>
#       <th>转速2</th>
#       <th>平台</th>
#       <th>显示</th>
#       <th>安装</th>
#       <th>颜色</th>
#       <th>国家</th>
#       <th>国家2</th>
#       <th>销量</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>W</td>
#       <td>M</td>
#       <td>1</td>
#       <td>2</td>
#       <td>P</td>
#       <td>2</td>
#       <td>6</td>
#       <td>0</td>
#       <td>8</td>
#       <td>W</td>
#       <td>1530</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>W</td>
#       <td>M</td>
#       <td>1</td>
#       <td>2</td>
#       <td>L</td>
# ...

# %%
data_size['销量'].boxplot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-e119a5e4c1d4> in <module>()
# ----> 1 data_size['销量'].boxplot()
#
# D:\develop\Anaconda\envs\python35\lib\site-packages\pandas\core\groupby.py in __getattr__(self, attr)
#     549
#     550         raise AttributeError("%r object has no attribute %r" %
# --> 551                              (type(self).__name__, attr))
#     552
#     553     plot = property(GroupByPlot)
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'boxplot'

# %%
df4=pd.DataFrame(data_size['销量'])
boxplots=df4.boxplot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\develop\Anaconda\envs\python35\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     336             try:
# --> 337                 arr = np.array(data, dtype=dtype, copy=copy)
#     338             except (ValueError, TypeError) as e:
#
# ValueError: setting an array element with a sequence
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-83e6692324d3> in <module>()
# ----> 1 df4=pd.DataFrame(data_size['销量'])
#       2 boxplots=df4.boxplot()
#
# D:\develop\Anaconda\envs\python35\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     339                 exc = TypeError('DataFrame constructor called with '
# ...

# %%
data_size['尺寸'].value_counts()
# Out:
# 尺寸  尺寸
# D   D     14
# M   M     93
# S   S     23
# Name: 尺寸, dtype: int64

# %%
data_size.head(10)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>产品代号</th>
#       <th>尺寸</th>
#       <th>转速1</th>
#       <th>转速2</th>
#       <th>平台</th>
#       <th>显示</th>
#       <th>安装</th>
#       <th>颜色</th>
#       <th>国家</th>
#       <th>国家2</th>
#       <th>销量</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>W</td>
#       <td>M</td>
#       <td>1</td>
#       <td>2</td>
#       <td>P</td>
#       <td>2</td>
#       <td>6</td>
#       <td>0</td>
#       <td>8</td>
#       <td>W</td>
#       <td>1530</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>W</td>
#       <td>M</td>
#       <td>1</td>
#       <td>2</td>
#       <td>L</td>
# ...

# %%
data_size=df.groupby('尺寸')
data_size

# %%
dff = pd.DataFrame(data_size['销量'].sum())
dff
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>销量</th>
#     </tr>
#     <tr>
#       <th>尺寸</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>D</th>
#       <td>10904</td>
#     </tr>
#     <tr>
#       <th>M</th>
#       <td>145584</td>
#     </tr>
#     <tr>
#       <th>S</th>
#       <td>18493</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
dff.head(10)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>销量</th>
#     </tr>
#     <tr>
#       <th>尺寸</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>D</th>
#       <td>10904</td>
#     </tr>
#     <tr>
#       <th>M</th>
#       <td>145584</td>
#     </tr>
#     <tr>
#       <th>S</th>
#       <td>18493</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
fig = plt.figure()
fig.set(alpha=0.2)  # 设定图表颜色alpha参数

data_pic = data_size['销量'].sum()
dff=pd.DataFrame({u'销量':data_pic})
dff.plot(kind='bar', stacked=True)
plt.title(u"尺寸销量图")
plt.xlabel(u"销量") 
plt.ylabel(u"尺寸") 

plt.show()

# %%
data_size["销量"].sum().plot(title="尺寸",kind="pie",autopct='%.1f',figsize=(10, 10))

# %%
df['转速']=df['转速1']*df['转速2']
df.head(10)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>产品代号</th>
#       <th>尺寸</th>
#       <th>转速1</th>
#       <th>转速2</th>
#       <th>平台</th>
#       <th>显示</th>
#       <th>安装</th>
#       <th>颜色</th>
#       <th>国家</th>
#       <th>国家2</th>
#       <th>销量</th>
#       <th>转速</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>W</td>
#       <td>M</td>
#       <td>1</td>
#       <td>2</td>
#       <td>P</td>
#       <td>2</td>
#       <td>6</td>
#       <td>0</td>
#       <td>8</td>
#       <td>W</td>
#       <td>1530</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>W</td>
#       <td>M</td>
#       <td>1</td>
# ...

# %%
df['转速'].value_counts()
# Out:
# 2    60
# 0    50
# 4    15
# 5     3
# 6     2
# Name: 转速, dtype: int64

# %%
df=pd.read_excel(r'C:\Users\dell\Desktop\BX\指标\拆解\西门子洗衣机_cj.xlsx',sheetname='西门子洗衣机_销量')
df.head(10)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>产品代号</th>
#       <th>尺寸</th>
#       <th>转速1</th>
#       <th>转速2</th>
#       <th>平台</th>
#       <th>显示</th>
#       <th>安装</th>
#       <th>颜色</th>
#       <th>国家</th>
#       <th>国家2</th>
#       <th>销量</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>W</td>
#       <td>M</td>
#       <td>1</td>
#       <td>2</td>
#       <td>P</td>
#       <td>2</td>
#       <td>6</td>
#       <td>0</td>
#       <td>8</td>
#       <td>W</td>
#       <td>1530</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>W</td>
#       <td>M</td>
#       <td>1</td>
#       <td>2</td>
#       <td>L</td>
# ...

# %%
df['转速']=df['转速1']*1000+df['转速2']*100
df['转速'].value_counts()
# Out:
# 1200    60
# 1000    32
# 800     16
# 1400    15
# 1500     3
# 700      2
# 1600     2
# Name: 转速, dtype: int64

# %%
plt.rc('font', family='SimHei', size=13)
data_r=df.groupby('转速')
data_r["销量"].sum().plot(title="转速",kind="pie",autopct='%.1f',figsize=(15, 15))

# %%
plt.rc('font', family='SimHei', size=13)
data_plat=df.groupby('平台')
data_plat["销量"].sum().plot(title="平台",kind="pie",autopct='%.1f',figsize=(10, 10))

# %%
fig = plt.figure()
fig.set(alpha=0.2)  # 设定图表颜色alpha参数

data_pic = data_plat['销量'].sum()
dff=pd.DataFrame({u'销量':data_pic})
dff.plot(kind='bar', stacked=True)
plt.title(u"平台销量图")
plt.xlabel(u"销量") 
plt.ylabel(u"平台") 

plt.show()

# %%
data_plat=df.groupby('显示')
data_plat["销量"].sum().plot(title="显示",kind="pie",autopct='%.1f',figsize=(10, 10))

# %%
fig = plt.figure()
fig.set(alpha=0.2)  # 设定图表颜色alpha参数

data_pic = data_plat['销量'].sum()
dff=pd.DataFrame({u'销量':data_pic})
dff.plot(kind='bar', stacked=True)
plt.title(u"显示销量图")
plt.xlabel(u"显示") 
plt.ylabel(u"销量") 

plt.show()

# %%
labels=['洗衣机','洗衣干衣机','干衣机']  
X=[164077,10904,581]    
  
fig = plt.figure()  
plt.pie(X,labels=labels,autopct='%1.2f%%') #画饼图（数据，数据对应的标签，百分数保留两位小数点）  
plt.title("洗衣机类型占比")  
    
  
plt.show()

# %%
data_s=pd.read_excel(r'C:\Users\dell\Desktop\BX\指标\拆解\西门子洗衣机_cj.xlsx',sheetname='带平均销量')
data_s.head(10)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>产品代号</th>
#       <th>尺寸</th>
#       <th>转速1</th>
#       <th>转速2</th>
#       <th>平台</th>
#       <th>显示</th>
#       <th>安装</th>
#       <th>颜色</th>
#       <th>国家</th>
#       <th>国家2</th>
#       <th>销量</th>
#       <th>平均销量</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>W</td>
#       <td>M</td>
#       <td>0</td>
#       <td>8</td>
#       <td>X</td>
#       <td>0</td>
#       <td>6</td>
#       <td>8</td>
#       <td>1</td>
#       <td>W</td>
#       <td>154</td>
#       <td>5.500000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>W</td>
#       <td>M</td>
# ...

# %%
plt.rc('font', family='SimHei', size=13)
data_size=data_s.groupby('尺寸')
data_size["销量"].sum().plot(title="尺寸分布",kind="pie",autopct='%.1f',figsize=(10, 10))

# %%
data_s['转速']=data_s['转速1']*1000+data_s['转速2']*100
data_s['转速'].value_counts()
# Out:
# 1200    60
# 1000    32
# 800     16
# 1400    15
# 1500     3
# 700      2
# 1600     2
# Name: 转速, dtype: int64

# %%
data_r=data_s.groupby('转速')
data_pic = data_r['销量'].sum()
dff=pd.DataFrame({u'销量':data_pic})
dff.plot(kind='bar', stacked=True)
plt.title(u"转速-销量图")
plt.xlabel(u"转速") 
plt.ylabel(u"销量") 

plt.show()

# %%
data_s['转速'].sum()
# Out:
# 146900

# %%
dff
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>销量</th>
#     </tr>
#     <tr>
#       <th>转速</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>700</th>
#       <td>186</td>
#     </tr>
#     <tr>
#       <th>800</th>
#       <td>13742</td>
#     </tr>
#     <tr>
#       <th>1000</th>
#       <td>45545</td>
#     </tr>
#     <tr>
#       <th>1200</th>
#       <td>103078</td>
#     </tr>
#     <tr>
#       <th>1400</th>
#       <td>11091</td>
#     </tr>
#     <tr>
#       <th>1500</th>
#       <td>1280</td>
#     </tr>
#     <tr>
#       <th>1600</th>
#       <td>59</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data_pic
# Out:
# 转速
# 700        186
# 800      13742
# 1000     45545
# 1200    103078
# 1400     11091
# 1500      1280
# 1600        59
# Name: 销量, dtype: int64

# %%
data_color=data_s.groupby('颜色')
data_color["销量"].sum().plot(title="颜色分布",kind="pie",autopct='%.1f',figsize=(10, 10))

# %%
data_r["销量"].sum().plot(title="颜色分布",kind="pie",autopct='%.1f',figsize=(10, 10))
